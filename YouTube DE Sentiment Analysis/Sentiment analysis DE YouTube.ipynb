# %% [markdown]
# # **Youtube Trending Videos in Germany**
# ![YouTube German](https://scontent-ham3-1.xx.fbcdn.net/v/t1.6435-9/98999650_114060636985994_5200488797342531584_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=09cbfe&_nc_ohc=blCc_MrY-skAX_DvxcC&_nc_ht=scontent-ham3-1.xx&oh=00_AT_2v8KSLQ19fxQXyhFALoltbP_La-wddDuqNMIFCcfIPQ&oe=62C2166F)

# %% [markdown]
# The dataset used in the analysis was taken from Kaggle [here](https://www.kaggle.com/datasets/rsrishav/youtube-trending-video-dataset?select=DE_youtube_trending_data.csv).
#
# **Dataset description**: This dataset is a daily record of the top trending YouTube videos and it will be updated daily.
#
# **Content**: This dataset includes several months (and counting) of data on daily trending YouTube videos. Data is included for the IN, US, GB, DE, CA, FR, RU, BR, MX, KR, and JP regions (India, USA, Great Britain, Germany, Canada, France, Russia, Brazil, Mexico, South Korea, and, Japan respectively), with up to 200 listed trending videos per day.
#
# Each region’s data is in a separate file. Data includes the video title, channel title, publish time, tags, views, likes and dislikes, description, and comment count.
#
# *For this analysis in particular a dataset from Germany will be used.*
# *The version of the dataset was downloaded on 05.06.2022.*
#
# *Due to the fact that dataset itself exceeds GitHub's limit, in order to work it would need to be extracted from the provided zip archive.*

# %% [markdown]
# ## Checking Python version

# %%
import sys
print(sys.version)
# Out:
# 3.10.4 | packaged by conda-forge | (main, Mar 24 2022, 17:32:50) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# My intention is to test Python 3.10, its features and compatibility if I come across any of these points during the analysis. If not -- at least it should be able to do the job anyway.

# %% [markdown]
# ## Data Preparation

# %%
# Import section

# Data wrangling libraries
import pandas as pd
import numpy as np

# Sentiment analysis
from PIL import Image
import emoji

# String manipulation
import re
import itertools

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator
import plotly.graph_objs as go
from plotly.offline import iplot

# Language processing
#import nltk        #uncomment if needed
from nltk.corpus import stopwords

# %%
# Loading the dataset
yt_trending = pd.read_csv('DE_youtube_trending_data.csv', parse_dates=['publishedAt', 'trending_date'])

# %%
# Checking the dimensions
yt_trending.shape
# Out:
# (133342, 16)

# %%
# Having a look at the first 15 rows
yt_trending.head(15)
# Out:
#        video_id                                              title  \
# 0   KJi2qg5F-9E                     Bonez MC - HOLLYWOOD (Snippet)
# 1   K0vYnOn7wZI  Nik hat heftige Probleme in Köln! 😱😫 #1925 | K...
# 2   2bbn9b79LRc  Camper Tour 2020 - ROADTRIP durch Österreich |...
# 3   Zv-3qNnAMaM  Ich TESTE SHEIN BIKINIS (try on haul) - UNMÖGL...
# 4   7clgQLneouU  STATEMENT zu meinem BAN! 😒 | Bald vielleicht P...
# 5   g7vdQgRsTKc  Bayer unterliegt abgezockten Mailändern: Inter...
# 6   86gzh8jftSE             GEBRAUCHTER Schrott - Die neue Masche?
# 7   YECPzRfksl4  Erkennst DU den Song? (mit unsympathischTV) - ...
# 8   gi3VMMiFHVg   Giannis Gets Ejected After Headbutting Mo Wagner
# 9   6QPDHBdSnrM  Günstige Bikinis aus dem Internet testen .. *s...
# 10  9eF6skiBZ6Y  Hymer EXSIS-T 374 💥Modell 2021💥 Wohnmobil mit ...
# 11  sfSnSZL40MM     Für Adama Traore gibt's kein Tempolimit | DAZN
# 12  duIveFH5KmA  Erst nach Verlängerung. United steht im Halbfi...
# 13  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 14  TgEhIh6oU_o             AZET - XHEP (FEATURING MOZZIK) [REMIX]
#
#                  publishedAt                 channelId  \
# 0  2020-08-11 18:00:03+00:00  UCGh8tmH9x9njaI2mXfh2fyg
# 1  2020-08-11 17:00:09+00:00  UCnrvUg5MJWPDSrv_voT7AqA
# 2  2020-08-11 18:00:00+00:00  UCBt8RY61tvanrhkzeZdNICw
# 3  2020-08-12 09:00:08+00:00  UCccDoH6QpRCjjcMgl5f88wA
# 4  2020-08-11 12:00:02+00:00  UC8E8eD7mOcnMazJT4laKbFQ
# 5  2020-08-10 22:00:08+00:00  UCNxq-0KJ0N3C3QfUWhLxNkw
# 6  2020-08-11 17:00:05+00:00  UCzH549YlZhdhIqhtvz7XHmQ
# 7  2020-08-11 15:00:08+00:00  UCL5-tPmf_sttES7ZcYJRp5A
# 8  2020-08-12 02:30:32+00:00  UC9-OpMMVoNP5o10_Iyq7Ndw
# 9  2020-08-11 12:30:00+00:00  UCPf0PECedlIt6fM87lxyn8Q
# 10 2020-08-11 14:11:02+00:00  UCaK-hTwY_xRxWexrLJdKZQw
# 11 2020-08-12 07:23:29+00:00  UC-xsrwf4kG4b_SZDiKIhZqw
# 12 2020-08-10 22:12:59+00:00  UCNxq-0KJ0N3C3QfUWhLxNkw
# 13 2020-08-11 17:00:10+00:00  UC0ZV6M2THA81QT9hrVWJG3A
# 14 2020-08-10 22:00:09+00:00  UCDLPHv0SrvyUzct8UYQ9R_g
#
#                channelTitle  categoryId             trending_date  \
# 0                  CrhymeTV          10 2020-08-12 00:00:00+00:00
# 1                Köln 50667          24 2020-08-12 00:00:00+00:00
# 2                AnaJohnson          24 2020-08-12 00:00:00+00:00
# 3             Einfach Marci          24 2020-08-12 00:00:00+00:00
# 4                      Domo          24 2020-08-12 00:00:00+00:00
# 5   DAZN UEFA Europa League          17 2020-08-12 00:00:00+00:00
# 6                 AlexiBexi          24 2020-08-12 00:00:00+00:00
# 7     World Wide Wohnzimmer          24 2020-08-12 00:00:00+00:00
# 8           Bleacher Report          17 2020-08-12 00:00:00+00:00
# 9               Sonny Loops          26 2020-08-12 00:00:00+00:00
# 10            camperklatsch          19 2020-08-12 00:00:00+00:00
# 11                  DAZN_DE          17 2020-08-12 00:00:00+00:00
# 12  DAZN UEFA Europa League          17 2020-08-12 00:00:00+00:00
# 13             Apex Legends          20 2020-08-12 00:00:00+00:00
# 14                  KMNGANG          10 2020-08-12 00:00:00+00:00
#
#                                                  tags  view_count   likes  \
# 0   187|187 Strassenbande|BONEZ MC|RAF Camora|MAXW...      573902   69319
# 1   Köln|50667|RTL2|RTL|Serie|k50667|ganze folge|t...      381375   13637
# 2   camper tour|camper tour deutsch|camper tour de...      142296    9480
# 3                                              [None]       55640    3420
# 4   Papaplatte|papaplatte twitch best of|papaplatt...      233899   25251
# 5   Inter|Inter Mailand|Leverkusen|Bayer Leverkuse...      623938   12770
# 6                                              [None]      249531   17199
# 7   world wide wohnzimmer|worldwidewohnzimmer|twin...      470201   43045
# 8   bleacher report|br|nba|giannis|giannis antetok...      756814    8278
# 9   bikini try on|bikini try on haul|günstige|biki...      154766   11261
# 10  neue wohnmobile|kastenwagen wohnmobil test|cam...       50761     856
# 11  dazn|DAZN|DAZN Fußball|DAZN Sport|#DAZN|#DAZNl...      141985    4705
# 12  Bruno Fernandes|Fernandes|Manchester|Mancheste...      448181       0
# 13  Apex Legends|Apex Legends characters|new Apex ...     2381688  146740
# 14                                             [None]      881635   49416
#
#     dislikes  comment_count                                  thumbnail_link  \
# 0        970           3311  https://i.ytimg.com/vi/KJi2qg5F-9E/default.jpg
# 1        435            866  https://i.ytimg.com/vi/K0vYnOn7wZI/default.jpg
# 2        144            364  https://i.ytimg.com/vi/2bbn9b79LRc/default.jpg
# 3        124            229  https://i.ytimg.com/vi/Zv-3qNnAMaM/default.jpg
# 4        375           1051  https://i.ytimg.com/vi/7clgQLneouU/default.jpg
# 5        357           1514  https://i.ytimg.com/vi/g7vdQgRsTKc/default.jpg
# 6        304            812  https://i.ytimg.com/vi/86gzh8jftSE/default.jpg
# 7        369           1719  https://i.ytimg.com/vi/YECPzRfksl4/default.jpg
# 8        331           2441  https://i.ytimg.com/vi/gi3VMMiFHVg/default.jpg
# 9        673            733  https://i.ytimg.com/vi/6QPDHBdSnrM/default.jpg
# 10        25             53  https://i.ytimg.com/vi/9eF6skiBZ6Y/default.jpg
# 11        55            424  https://i.ytimg.com/vi/sfSnSZL40MM/default.jpg
# 12         0            902  https://i.ytimg.com/vi/duIveFH5KmA/default.jpg
# 13      2794          16549  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 14       969           2922  https://i.ytimg.com/vi/TgEhIh6oU_o/default.jpg
#
#     comments_disabled  ratings_disabled  \
# 0               False             False
# 1               False             False
# 2               False             False
# 3               False             False
# 4               False             False
# 5               False             False
# 6               False             False
# 7               False             False
# 8               False             False
# 9               False             False
# 10              False             False
# 11              False             False
# 12              False              True
# 13              False             False
# 14              False             False
#
#                                           description
# 0   Hollywood Fanbox vorbestellen ► http://bonezmc...
# 1   Toni gerät in Panik, als plötzlich ein Unbekan...
# 2   Mehr von unserem Trip quer durch Deutschland, ...
# 3   Heii Cuties,Was soll ich in kommender Zeit noc...
# 4   Domo hier! Abonnieren! Liken! Genießen!\r\rWen...
# 5   In Düsseldorf kommt es zum Viertelfinal-Duell ...
# 6   Gebrauchtes Zeug auf #SchinaSchrott Portalen.....
# 7   Zum dritten Mal dabei: Sascha kann's nicht las...
# 8   In a random and wild sequence of events, Giann...
# 9   Viel Spaß bei dem Bikini Try on Haul!Günstige ...
# 10  ❤️ Instagram: http://instagram.com/camperklats...
# 11  Was für eine Maschine. #DAZNmoment▶ Sichere di...
# 12  In einem langezeit chancenarmen Viertelfinale ...
# 13  While running her own modding shop, Ramya Pare...
# 14  FAST LIFE 2 ERSCHEINT AM 11.09.►FAST LIFE 2 BO...

# %% [markdown]
# ## Data Exploration

# %%
# Checking which years this dataset covers
yt_trending['publishedAt'].dt.year.unique()
# Out:
# array([2020, 2021, 2022], dtype=int64)

# %% [markdown]
# The dataset is fairly fresh, as it was expected. However, considering there is a `dislikes` column we will likely run into the issue when after some time the number of dislikes will be missing.

# %%
# Checking how many unique channels are included
yt_trending['channelTitle'].nunique()
# Out:
# 6048

# %%
# Checking for null values across the entire dataset
yt_trending.isna().sum()
# Out:
# video_id                0
# title                   0
# publishedAt             0
# channelId               0
# channelTitle            0
# categoryId              0
# trending_date           0
# tags                    0
# view_count              0
# likes                   0
# dislikes                0
# comment_count           0
# thumbnail_link          0
# comments_disabled       0
# ratings_disabled        0
# description          3662
# dtype: int64

# %% [markdown]
# As we can see, no dislikes are missing from the dataset and, therefore, they are, probably, set to zero instead.

# %%
(yt_trending.dislikes == 0).sum()
# Out:
# 35368

# %%
(yt_trending.dislikes != 0).sum()
# Out:
# 97974

# %% [markdown]
# The sum should be around 133k which corresponds to the total number of entries, meaning that indeed when dislikes were disabled by YouTube in this dataset they were set to zero. Naturally, it is also taken into account that some videos had 0 dislikes to begin with.
#
# We will have a detailed look at it in the next section.

# %% [markdown]
# ### Short summary
# The dataset contains data on trending YouTube videos of 6048 channels across the three years (2020, 2021, 2022).
#
# Additionally, in 3662 entries there are missing descriptions.
#
# Also, after some point in time all the dislikes have a value of zero.

# %% [markdown]
# ## Handling the missing descriptions
#
# Due to descriptions being plain text, a reasonable way to handle the missing one, would be to replace them with a clear indication that the description is missing.

# %%
yt_trending['description'] = yt_trending['description'].fillna('The description was not provided!')

# %%
# Checking for null values across the entire dataset once more
yt_trending.isna().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# dtype: int64

# %% [markdown]
# ## Dealing with the dislike count
#
# As we are doing a sentiment analysis here and not a machine learning, there is no real need to somehow manipulate the data for the sake of dislikes.
# However, when later on we will be *SPOILER xD* having a look at the relationship between views and dislikes, we wouldn't be able to fit linear regression to the entire dataset properly. Therefore, we need to locate the date when dislikes were disabled and select that as a cutoff point for our regression.
#
# While we could, naturally start with a straightforward approach of looking directly at the data, I opted out to make it a little bit easier for myself and used Google.
#
# YouTube dislikes were disabled starting at 01.11.2021. But there is one catch...

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=yt_trending, x = 'publishedAt', y = 'dislikes')
# Out:
# <AxesSubplot:xlabel='publishedAt', ylabel='dislikes'>

# %% [markdown]
# It looks like the dislikes didn't really go away in November...
#
# The reason is simple: this dataset was not scrapped but collected using YouTube's API. And, it turns out, that in the API dislikes were available up to the 13th of December 2021 (excluded).
#
# That explains a lot. Now let's have a closer look at this period to find the timestamp with the last published video with dislikes count.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=yt_trending[(yt_trending.publishedAt > "2021-12-12 17:30:00")
             & (yt_trending.publishedAt < "2021-12-13 01:01:00")],
             x = 'publishedAt',
             y = 'dislikes')
# Out:
# <AxesSubplot:xlabel='publishedAt', ylabel='dislikes'>

# %% [markdown]
# Apparently, some time before 20:00 of 12.12.2021 the last video with non-zero dislikes was published.
#
# Knowing that, let's try to locate the index of that entry and see the concrete time.

# %%
yt_trending[(yt_trending.publishedAt > "2021-12-12 19:00:00")
             & (yt_trending.publishedAt < "2021-12-14")
             & (yt_trending.dislikes != 0)].sort_values(by='publishedAt')
# Out:
#           video_id                                              title  \
# 98353  0l5M2TtB8j4  High End Elektro-Sportler: Audi RS e-tron GT v...
# 98359  AL__lS856ug   Max Verstappen is 2021 Formula 1 World Champion!
# 98362  neGW0_e8zwc  Bin geflasht von der heutigen Leistung I Press...
#
#                     publishedAt                 channelId  \
# 98353 2021-12-12 19:15:01+00:00  UCak3selG2oi5vn7sbqdaULA
# 98359 2021-12-12 19:45:07+00:00  UCQIyqMWCdx1GBvbw_Yi6lEA
# 98362 2021-12-12 19:49:04+00:00  UCDFp4bscTFm8hYxCBx-tIXg
#
#                   channelTitle  categoryId             trending_date  \
# 98353  GRIP - Das Motormagazin           2 2021-12-13 00:00:00+00:00
# 98359    Red Bull Racing Honda          17 2021-12-13 00:00:00+00:00
# 98362      Eintracht Frankfurt          17 2021-12-13 00:00:00+00:00
#
#                                                     tags  view_count  likes  \
# 98353  GRIP|RTL2|Motormagazin|RTLZWEI|Grip Hamid|Grip...      143908   5986
# 98359  Red Bull Racing|Red Bull F1|Red Bull Red Bull ...      554720  35296
# 98362  Eintracht Frankfurt|Eintracht|Frankfurt|SGE|Ei...       29116   1055
#
#        dislikes  comment_count  \
# 98353       189            515
# 98359       478           1792
# 98362         8            175
#
#                                        thumbnail_link  comments_disabled  \
# 98353  https://i.ytimg.com/vi/0l5M2TtB8j4/default.jpg              False
# 98359  https://i.ytimg.com/vi/AL__lS856ug/default.jpg              False
# 98362  https://i.ytimg.com/vi/neGW0_e8zwc/default.jpg              False
#
#        ratings_disabled                                        description
# 98353             False  Sie sind die Speerspitzen von Porsche und Audi...
# 98359             False  Ladies and Gentlemen, we have a brand-new Worl...
# 98362             False  Die Pressekonferenz der beiden Trainer nach de...

# %% [markdown]
# Here, entry 98362 is our cutoff point. And yet, we cannot just use index for slicing. Let's have a look at the next index.

# %%
yt_trending.loc[98363]
# Out:
# video_id                                                   XBiG1LBLSBA
# title                                     Wenn Opas Eis essen wollen 😂
# publishedAt                                  2021-12-11 19:39:56+00:00
# channelId                                     UCj9Co34VgEC2z7OtJzLJQQQ
# channelTitle                                           Mehmetaberloyal
# categoryId                                                          22
# trending_date                                2021-12-13 00:00:00+00:00
# tags                                                            [None]
# view_count                                                      280337
# likes                                                            34372
# dislikes                                                           424
# comment_count                                                       84
# thumbnail_link          https://i.ytimg.com/vi/XBiG1LBLSBA/default.jpg
# comments_disabled                                                False
# ratings_disabled                                                 False
# description          Offizieller Channel von Mehmetaberloyal💫Auch a...
# Name: 98363, dtype: object

# %% [markdown]
# The dislike count is non-zero. The reason is that despite being the next item in terms of index, this entry has completely different publishing date. We could have avoided this by sorting the data by publishing date, but it's not a problem since we are aware of the fact and will use the filtering by timestamps anyway.
#
# Now we know that the last video with dislikes was published on 2021-12-12 19:49:04. We can use this later on.

# %%
yt_trending_with_dislikes = yt_trending[(yt_trending.publishedAt < '2021-12-12 19:49:05')]
yt_trending_with_dislikes.shape
# Out:
# (99034, 16)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Correlation

# %%
# Just to have a look at all columns without scrolling up
list(yt_trending.columns)
# Out:
# ['video_id',
#  'title',
#  'publishedAt',
#  'channelId',
#  'channelTitle',
#  'categoryId',
#  'trending_date',
#  'tags',
#  'view_count',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'thumbnail_link',
#  'comments_disabled',
#  'ratings_disabled',
#  'description']

# %% [markdown]
# #### Accounting for all dislikes

# %%
# Basic correlation matrix
yt_trending_corr = yt_trending[['view_count', 'likes', 'dislikes', 'comment_count']]
yt_trending_corr.corr()
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.841933  0.633250       0.496432
# likes            0.841933  1.000000  0.588478       0.674813
# dislikes         0.633250  0.588478  1.000000       0.508879
# comment_count    0.496432  0.674813  0.508879       1.000000

# %%
# Correlation heatmap
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(yt_trending_corr.corr(), vmin=-1, vmax=1, annot=True, fmt='.2%')
heatmap.set_title('Correlation Heatmap (entire dataset)', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap (entire dataset)')

# %% [markdown]
# As expected, we see a strong correlation between `view count` and `likes`. A moderate correlation between `view count` and `comment count` is also observed. But both of these statements make sense: in order to like or comment a video people almost always watch it first.
#
# Besides that, we see that people who liked the video are more likely to leave a comment unlike those who disliked it.
#
# While, I imagine, the trend would remain the same, let's have a look at the dataset with valid dislikes.

# %% [markdown]
# #### Accounting for factual dislikes

# %%
yt_trending_corr_ds = yt_trending_with_dislikes[['view_count', 'likes', 'dislikes', 'comment_count']]
yt_trending_corr_ds.corr()
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.839132  0.714920       0.531750
# likes            0.839132  1.000000  0.644367       0.710975
# dislikes         0.714920  0.644367  1.000000       0.512274
# comment_count    0.531750  0.710975  0.512274       1.000000

# %%
# Correlation heatmap
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(yt_trending_corr_ds.corr(), vmin=-1, vmax=1, annot=True, fmt='.2%')
heatmap.set_title('Correlation Heatmap (dataset with valid dislikes)', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap (dataset with valid dislikes)')

# %% [markdown]
# Now we still observe strong correlation between `view count` and `likes`, but also a decent correlation of the former with `dislikes`.
#
# Here it is much clearer that people who leave a like would also possibly leave a comment.

# %% [markdown]
# #### Comparing linear relationships

# %%
# Likes

plt.figure(figsize=(10, 8))
sns.regplot(data=yt_trending, x='view_count', y='likes', ci=None).set(title='Views vs likes')
# Out:
# [Text(0.5, 1.0, 'Views vs likes')]

# %% [markdown]
# This graph visually shows a quite nice linear relationship between views and likes.

# %%
# Dislikes

fig, axs = plt.subplots(1, 2, sharey=True, figsize=(17, 8))

# Entire dataset
sns.regplot(data=yt_trending, x='view_count', y='dislikes',
            ci=None, color = 'red', ax=axs[0]).set(title='Entire dataset')
# Dataset with valid dislikes
sns.regplot(data=yt_trending_with_dislikes, x='view_count', y='dislikes',
            ci=None, color = 'red', ax=axs[1]).set(title='Dataset with valid dislikes')
# Out:
# [Text(0.5, 1.0, 'Dataset with valid dislikes')]

# %% [markdown]
# As for dislikes the relationship is still linear, but the correlation is much lower which is noticeable by looking at the slope. Also, it is clear from the entire dataset, that dislikes with a value of 0 indeed skew the regression decreasing the slope even further.

# %% [markdown]
# Notice a high correlation between views and likes. That makes sense!
# people who like a video tend to leave a comment and vice versa. Howver people who dislike tend not to leave a comment or vice versa.

# %% [markdown]
# ### Most (un)/popular videos

# %%
# Just to have a look at all columns without scrolling up
list(yt_trending.columns)
# Out:
# ['video_id',
#  'title',
#  'publishedAt',
#  'channelId',
#  'channelTitle',
#  'categoryId',
#  'trending_date',
#  'tags',
#  'view_count',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'thumbnail_link',
#  'comments_disabled',
#  'ratings_disabled',
#  'description']

# %% [markdown]
# #### Videos with the most likes

# %%
# The most liked video
yt_trending.loc[yt_trending['likes'].idxmax()]
# Out:
# video_id                                                   gdZLi9oWNZg
# title                               BTS (방탄소년단) 'Dynamite' Official MV
# publishedAt                                  2020-08-21 03:58:10+00:00
# channelId                                     UC3IZKseVpdzPSBaWxBxundA
# channelTitle                                            Big Hit Labels
# categoryId                                                          10
# trending_date                                2020-08-27 00:00:00+00:00
# tags                                   BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# view_count                                                   219110491
# likes                                                         15460845
# dislikes                                                        674292
# comment_count                                                  5810618
# thumbnail_link          https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg
# comments_disabled                                                False
# ratings_disabled                                                 False
# description          BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# Name: 3152, dtype: object

# %%
# TOP 10 most liked videos
top10_likes = (yt_trending[['title', 'likes']].groupby('title')
                                .sum()
                                .sort_values(by = 'likes', ascending = False)
                                .head(10)
                                .reset_index()
                                .rename(columns={'title': 'Title', 'likes': 'Cumulative likes'}))

top10_likes.index = top10_likes.index + 1   # considering Python starts numeration from 0, I would add 1 to index to make it look nicer

top10_likes
# Out:
#                                                 Title  Cumulative likes
# 1                  BTS (방탄소년단) 'Dynamite' Official MV          91448368
# 2                                 LISA - 'LALISA' M/V          74742321
# 3       BTS (방탄소년단) 'Permission to Dance' Official MV          69665035
# 4     BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V          68359343
# 5                   $456,000 Squid Game In Real Life!          48577517
# 6   Crazy #alluarjun #painting  #shorts #viral #tr...          47168648
# 7                    BLACKPINK – ‘Lovesick Girls’ M/V          45530096
# 8              BTS (방탄소년단) 'Life Goes On' Official MV          44825781
# 9    PSY - 'That That (prod. & feat. SUGA of BTS)' MV          38823209
# 10                EXO 엑소 'Don't fight the feeling' MV          38638071

# %% [markdown]
# #### Videos with the most dislikes

# %%
# The most disliked video
yt_trending.loc[yt_trending['dislikes'].idxmax()]
# Out:
# video_id                                                   vRXZj0DzXIA
# title                  BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V
# publishedAt                                  2020-08-28 04:00:11+00:00
# channelId                                     UCOmHUn--16B90oW2L6FRR3A
# channelTitle                                                 BLACKPINK
# categoryId                                                          10
# trending_date                                2020-09-03 00:00:00+00:00
# tags                 YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...
# view_count                                                   167334429
# likes                                                         11474616
# dislikes                                                        848975
# comment_count                                                  2710904
# thumbnail_link          https://i.ytimg.com/vi/vRXZj0DzXIA/default.jpg
# comments_disabled                                                False
# ratings_disabled                                                 False
# description          BLACKPINK - ‘Ice Cream (with Selena Gomez)’Com...
# Name: 4582, dtype: object

# %%
# TOP 10 most disliked videos
top10_dislikes = (yt_trending[['title', 'dislikes']].groupby('title')
                                .sum()
                                .sort_values(by = 'dislikes', ascending = False)
                                .head(10)
                                .reset_index()
                                .rename(columns={'title': 'Title', 'dislikes': 'Cumulative dislikes'}))

top10_dislikes.index = top10_dislikes.index + 1   # considering Python starts numeration from 0, I would add 1 to index to make it look nicer

top10_dislikes
# Out:
#                                                 Title  Cumulative dislikes
# 1     BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V              4995212
# 2                  BTS (방탄소년단) 'Dynamite' Official MV              3553916
# 3                  Guess the sound challenge🎵 #shorts              1125189
# 4                      HOW CRYPTOCURRENCY WORKS 💸👨🏻‍💻              1109455
# 5               Merve Yalçın - Bella (Official Video)              1086459
# 6                MvRyhan Funny videos #tiktok #Shorts               934935
# 7                 Dream - Mask (Official Music Video)               930022
# 8   Spider-Man saved the girl from the Villain 😱❤️...               830212
# 9                    Элджей & MORGENSHTERN - Lollipop               698461
# 10                   Turn into egg - Tutorial #Shorts               665384

# %% [markdown]
# #### Videos with the most comments

# %%
# The most commented video
yt_trending.loc[yt_trending['comment_count'].idxmax()]
# Out:
# video_id                                                   WMweEpGlu_U
# title                                 BTS (방탄소년단) 'Butter' Official MV
# publishedAt                                  2021-05-21 03:46:13+00:00
# channelId                                     UC3IZKseVpdzPSBaWxBxundA
# channelTitle                                               HYBE LABELS
# categoryId                                                          10
# trending_date                                2021-05-23 00:00:00+00:00
# tags                                   BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# view_count                                                   166895681
# likes                                                         14202546
# dislikes                                                         51664
# comment_count                                                  5987755
# thumbnail_link          https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg
# comments_disabled                                                False
# ratings_disabled                                                 False
# description          BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# Name: 55952, dtype: object

# %%
# TOP 10 most commented videos
top10_com = (yt_trending[['title', 'comment_count']].groupby('title')
                                .sum()
                                .sort_values(by = 'comment_count', ascending = False)
                                .head(10)
                                .reset_index()
                                .rename(columns={'title': 'Title', 'comment_count': 'Cumulative comment count'}))

top10_com.index = top10_com.index + 1   # considering Python starts numeration from 0, I would add 1 to index to make it look nicer

top10_com
# Out:
#                                                 Title  \
# 1                  BTS (방탄소년단) 'Dynamite' Official MV
# 2                 EXO 엑소 'Don't fight the feeling' MV
# 3     BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V
# 4              BTS (방탄소년단) 'Life Goes On' Official MV
# 5       BTS (방탄소년단) 'Permission to Dance' Official MV
# 6                                 LISA - 'LALISA' M/V
# 7   GAME  (Full Video)  Shooter Kahlon | Sidhu Moo...
# 8                    BTS (방탄소년단) 'Butter' Official MV
# 9                  BTS (방탄소년단) 'Film out' Official MV
# 10                             TWICE Alcohol-Free M/V
#
#     Cumulative comment count
# 1                   35601303
# 2                   25677362
# 3                   17732864
# 4                   17662066
# 5                   17455673
# 6                   17260976
# 7                   16059063
# 8                   14985314
# 9                   11321689
# 10                   8379302

# %% [markdown]
# ### Sentiment analysis

# %% [markdown]
# #### Tags

# %% [markdown]
# Now let's have a look at tags. In order to analyze them we will put them in a single string.

# %%
tags_string = ''.join(yt_trending.tags)

# %%
tags_string[:500]
# Out:
# '187|187 Strassenbande|BONEZ MC|RAF Camora|MAXWELL|rap|hiphop|deutschrap|CrhymeTV|strassenbande|gzuz|lx|maxwell|sa4|bonez|raf|camora|ghost|schnapp|500 ps|ohne mein team|honda civic|millionär|mit den jungs|haifischnikez|Bonez MC - Tilidin weg|bonez tilidin|Tilidin weg|bonez zombiez|bonez tilidin weg|bonezmc hollywood|hollywood|snippet|hollywood snippetKöln|50667|RTL2|RTL|Serie|k50667|ganze folge|tv now|preview|stream|ganze folge köln|soap köln|preview köln|Stella Köln 50667|oskar köln 50667|janine'

# %% [markdown]
# All right, naturally, our tags string contains special letters. Not only those, that separate tags, but also some other characters from different languages or emojis. Let's have a look at those. However, we, obviously, want to remove any special characters BUT German letters which are considered to be such in this case.

# %%
# Having a look at spec. chars while not considering German letters as such
spec_chrs = set(re.findall('[^A-Za-z0-9äöüÄÖÜß]', tags_string))

# %%
print('1' in tags_string)
# Out:
# True

# %%
# Taking a look at a few items
small_set = set(itertools.islice(spec_chrs, 15))
small_set
# Out:
# {'Đ', 'ş', 'ا', 'ل', '乱', '日', '阿', '긴', '룹', '름', '창', '택', '틱', 'Ｆ', 'ｓ'}

# %%
# Checking for German characters leaking into a special characters set
for letter in ["1", "ä","ö", "ü", "Ä","Ö", "Ü", "ß"]:
    print(letter in spec_chrs, end=" ")
# Out:
# False False False False False False False False

# %% [markdown]
# Good, now that we are in a clear, let's use the same pattern and replace all the special characters with spaces.

# %%
# sp stands for spaces. We will see that some elements in the resulting string have multiple of those
tags_sp = re.sub('[^A-Za-z0-9äöüÄÖÜß]', ' ', tags_string)

# %%
tags_sp[:500]
# Out:
# '187 187 Strassenbande BONEZ MC RAF Camora MAXWELL rap hiphop deutschrap CrhymeTV strassenbande gzuz lx maxwell sa4 bonez raf camora ghost schnapp 500 ps ohne mein team honda civic millionär mit den jungs haifischnikez Bonez MC   Tilidin weg bonez tilidin Tilidin weg bonez zombiez bonez tilidin weg bonezmc hollywood hollywood snippet hollywood snippetKöln 50667 RTL2 RTL Serie k50667 ganze folge tv now preview stream ganze folge köln soap köln preview köln Stella Köln 50667 oskar köln 50667 janine'

# %% [markdown]
# Indeed, in some cases this resulted in multiple spaces. Let's remove those promptly.

# %%
tags = " ".join(tags_sp.split())
tags[:500]
# Out:
# '187 187 Strassenbande BONEZ MC RAF Camora MAXWELL rap hiphop deutschrap CrhymeTV strassenbande gzuz lx maxwell sa4 bonez raf camora ghost schnapp 500 ps ohne mein team honda civic millionär mit den jungs haifischnikez Bonez MC Tilidin weg bonez tilidin Tilidin weg bonez zombiez bonez tilidin weg bonezmc hollywood hollywood snippet hollywood snippetKöln 50667 RTL2 RTL Serie k50667 ganze folge tv now preview stream ganze folge köln soap köln preview köln Stella Köln 50667 oskar köln 50667 janine p'

# %% [markdown]
# Looks fine! Now it's time for the word cloud.

# %% [markdown]
# #### Word Cloud

# %% [markdown]
# A normal thing to when creating a word cloud is to use a list of stop words which are not considered: he, she, an, the, etc. However here we are dealing with German words, therefore we need a list with German stop words.

# %%
# This might be needed if the next cell gives an error

# nltk.download('stopwords')

# %%
german_stop_words = stopwords.words('german')
german_stop_words[92]
# Out:
# 'für'

# %% [markdown]
# Now that it works let's create the word cloud itself.

# %%
# Word cloud
wordcloud= WordCloud(width= 2000, height= 1000, stopwords= set(german_stop_words)).generate(tags)

# %%
# Display
plt.figure(figsize=(25,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Generate a word cloud image
mask = np.array(Image.open("pi5rbeBMT.png"))
wordcloud_de = WordCloud(stopwords=german_stop_words, background_color="white", mode="RGBA", max_words=1000, mask=mask).generate(tags)

# Create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[25,10])
plt.imshow(wordcloud_de.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")

# Display
plt.show()

# %% [markdown]
# First of all, there are two visualizations due to the fact I wanted to create the second one looking as the German flag. The result is...meh. But, luckily, we have the first one that looks better visually.
#
# Now as for the insights it seems that Germans really **REALLY** love football :)
# DAZN - is a sport streaming service. Then we see that they enjoy some music, some games, some comedy series.

# %% [markdown]
# #### Emoji analysis

# %% [markdown]
# Now let's analyse the emojis used in video titles. For this we will use a special Python package and the fact that each emoji corresponds to a unicode.

# %%
# Placeholder string
em_str = ''

# Iterator
for i in yt_trending.title:
    # Checking if a character belongs to emoji
    temp = [x for x in i if x in emoji.EMOJI_DATA]
    # If emoji then add it to the placeholder string
    for emji in temp:
        em_str += emji

# %%
# Check a few elements
em_str[:500]
# Out:
# '😱😫😒💥💥💥😲🤔🔥☠☠😍👍🙅♂👎😨😍🌳🌳😱🔥😍🤬😱🥵✝📍🎂❤😳😳🍒🍍🍎👍😳⚔😱🏠❤⚽🥞🆘🍅😲😲😅😂😳💓🙏🏻😬👀😱😫😒💥💥💥⭐🔥👿😲🤔🔥😍👍🙅♂👎☠☠😍🌳🌳😨🔥😍🤬😱😱🥵✝📍🍒🍍🍎😯🙀🥴❤❌🥵😅😳😂💓🙏🏻⭐🔥😱😫😬👀💥💥💥😒👿😲🤔🔥😍☠☠👅⚽💋😯😱🤷♂👀❤🥴😡🙀😥😣🥵😳😂⭐🔥😅💓🙏🏻😱😫💥💥💥😒👿🤯🤯😨📘📂🦋👅💋😯❌🔴⚽🤷♂👀❤❤😡😱🥴🙀🥵⭐🔥😥😣😳😂😅💓🙏🏻😬👀♥🤐™🍰👌⚡🌧🤯🤯😨🏠⚽✔🍰👅😱💋❌😯📘📂🦋🔴😡🤷♂👀❤❤⚽🥴🙀⭐🔥🥵😥😣😱🤔🤥™♥🤐😱😰🏎🍗🤤⚡🌧🍰👌🤯🤯😨🏠⚽✔🍰👅😱💋❌😯😡📘📂🦋⚽🔴😱😳😮™😡♥🤐😱😰🏎🍗🤤⚡🌧🍰👌🤯🤯😨🏠⚽✔🍰😱👅😍😳😴😕🙈😱🔥❤💔😱😳😮🤔🤥😡™🏎♥🤐😱😰🍗🤤⚡🌧🍰👌🤯🤯😨🏠⚽☢😱😮💥😍😳😴😕🙈😱🔥❤💔😱😳😮😡™🏎🍗🤤⚡🌧♥🤐🍰👌😍💘🔥🙈☢®😱🤨😶😍😕🙈😳😴😱🔥❤💔😱😳😮😡⚖😍💘😧😏☢🔥🙈®😱😮💥🤨😶😍😕🙈😳😴😱🔥❤💔😱🏆😍🥇📦😂📗🦎👨🏻🍳😳⚖🎙😍💘😧😏🔥🙈☢®😮💥😱🤨😶😍😕🙈💥💘😲💥🍑🏆😳🙄☢❤📦😂🥇👔⚽😭😭😍📗🦎🤔🔥⚖👨🏻🍳😳😍💘😧😏🔥🙈☢®😮💥😱😢💔💥🍑💄💥💘😲❤💔🙊😱🏡📦😂🏆☢❤😳🙄👔⚽😭😭🥇😍📗🦎⚖👨🏻🍳🤔🔥😳😧😍💘😏🔥🙈☢®®💄❤💔😢💔💥🍑'

# %%
# Number of elements with duplicates
len(em_str)
# Out:
# 35975

# %%
# Creating a dictionary to count occurrence of each emoji
result={}
for i in set(em_str):
    result[i]= em_str.count(i)

# %%
# Show some of the results
set(itertools.islice(result.items(), 15))
# Out:
# {('☺', 5),
#  ('❎', 36),
#  ('🍿', 26),
#  ('🎉', 113),
#  ('🏈', 3),
#  ('🏝', 75),
#  ('💀', 96),
#  ('💏', 33),
#  ('💫', 30),
#  ('📻', 4),
#  ('🔵', 19),
#  ('🤔', 409),
#  ('🤝', 43),
#  ('🧈', 5),
#  ('🧊', 46)}

# %%
# Created a sorted list with emojis count
emj_sorted = sorted(result.items(), key = lambda x: x[1], reverse = True)
emj_sorted[:15]
# Out:
# [('😂', 2328),
#  ('😱', 2118),
#  ('🔥', 1977),
#  ('😍', 1699),
#  ('😳', 1288),
#  ('❤', 779),
#  ('🤯', 577),
#  ('💥', 523),
#  ('🏼', 503),
#  ('💔', 498),
#  ('😲', 464),
#  ('🏻', 414),
#  ('®', 414),
#  ('🤔', 409),
#  ('❌', 387)]

# %%
emj_df = pd.DataFrame(emj_sorted[:15], columns = ["Emoji", "Count"], index = None)
emj_df
# Out:
#    Emoji  Count
# 0      😂   2328
# 1      😱   2118
# 2      🔥   1977
# 3      😍   1699
# 4      😳   1288
# 5      ❤    779
# 6      🤯    577
# 7      💥    523
# 8      🏼    503
# 9      💔    498
# 10     😲    464
# 11     🏻    414
# 12     ®    414
# 13     🤔    409
# 14     ❌    387

# %% [markdown]
# Now, one final visualization! We will use Plotly for it supports emoji as labels.

# %%
chart = go.Bar(x = emj_df['Emoji'],
               y = emj_df['Count'])

iplot([chart])
